# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy as astro 
import pandas as pd
import math 
import scipy 
# %matplotlib inline

# %%
from pylab import imshow
from numpy import random
from PIL import Image
from numpy.linalg import inv
from __future__ import division
from matplotlib import gridspec
from matplotlib import colorbar
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy import stats
from astropy.visualization import astropy_mpl_style #color/plotting
plt.style.use(astropy_mpl_style)

# %%
#Part one: creating Inital and Hitmap

# %%
#random white noisemap 
x_dim=50
y_dim=50
A_n=1 #number will be computed 
WNMap=np.random.randn(x_dim,y_dim)*A_n
#Hitmap=np.random.randint(0,10,shape=5)
#np.clip(Hitmap,0,10)
plt.colorbar(imshow(WNMap))
imshow(WNMap)
plt.savefig('1')
#print('Array of Hitmap',Hitmap)

# %%
#First A_noise calculation 
Mean=np.mean(WNMap)
print(Mean)
# Out:
# 0.029724953807999673

# %%
#Hitsmap 

Hitsmap=np.ones([x_dim,y_dim])
offset=10
Hitsmap[x_dim//2-offset:x_dim//2+offset,y_dim//2-offset:y_dim//2+offset]=5
imshow(Hitsmap)
plt.savefig('2')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-cd00eaf9c494> in <module>
#       5 Hitsmap[x_dim//2-offset:x_dim//2+offset,y_dim//2-offset:y_dim//2+offset]=5
#       6 imshow(Hitsmap)
# ----> 7 plt.colorbar(Hitsmap)
#       8 plt.savefig('2')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2192     if ax is None:
#    2193         ax = gca()
# -> 2194     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2195     return ret
#    2196 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2341                              'panchor']
#    2342         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# ...

# %%
NMap=WNMap/Hitsmap
print(NMap)
imshow(NMap)
plt.savefig('2')
# Out:
# [[-0.09104715 -0.03972882  0.66451155 ...  0.17929597  0.00564381
#   -0.05179976]
#  [ 1.83321053  1.20528414  2.42747687 ...  1.73205136  0.76772094
#   -0.76231033]
#  [ 0.47988265  0.20811116  0.50148279 ...  0.22045687  0.94907625
#   -1.82417918]
#  ...
#  [ 1.49395487  1.24189619  1.16507546 ...  1.91797271 -0.45773469
#    1.59521923]
#  [-1.40535289  1.36346935 -0.59654483 ... -0.27210428 -1.30459665
#   -0.2228025 ]
#  [-0.29917439  0.42731108  0.46492238 ...  1.16634388  0.54848064
#    0.86170057]]

# %%
Inital=np.random.rand(x_dim,y_dim)*A_n
np.clip(Inital,0,10)

#mean=0
#dev=0.0,1.0

#M=np.mean(Inital)
#print(M)

plt.colorbar(imshow(Inital,vmin=0,vmax=1))
imshow(Inital)

# %%
Noisemap=Inital/Hitmap 
np.clip(Noisemap,0,10)
plt.colorbar(imshow(Noisemap,vmin=0,vmax=1))
imshow(Noisemap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-479bd8b78e54> in <module>
# ----> 1 Noisemap=Inital/Hitmap
#       2 np.clip(Noisemap,0,10)
#       3 plt.colorbar(imshow(Noisemap,vmin=0,vmax=1))
#       4 imshow(Noisemap)
#
# NameError: name 'Hitmap' is not defined

# %%
fig = plt.figure(figsize=(20, 7), dpi=100)
gs = gridspec.GridSpec(1, 3, figure=fig)
#ax2 = fig.add_subplot(gs[1, 0])

# %%
ax1 = fig.add_subplot(gs[0, 0])
ax2=fig.add_subplot(gs[0, 1],sharey=ax1)
ax3=fig.add_subplot(gs[0, 2],sharey=ax2)

# %%
ax1.imshow(Hitmap)
ax2.imshow(Inital)
ax3.imshow(Noisemap)
#plt.savefig('Figures.pdf')
plt.show()

# %%
fig,axx = plt.subplots(figsize=(8,8), dpi=100, nrows=1, ncols=3)
axx[0].imshow(Inital)
axx[1].imshow(Hitmap)
axx[2].imshow(Noisemap)

plt.tight_layout()

#plt.imshow(Noisemap)
#ax.cax.colorbar(im)
#ax.cax.toggle_label(True)

#fig.colorbar(im, ax=axx.ravel().tolist())

#fig.colorbar(imshow(Noisemap))
plt.show()
#plt.savefig('Tripple1.pdf')

# %%
#A check of something

x=Hitmap/Noisemap
np.clip(x,0,1)
imshow(x)
plt.colorbar(imshow(x,vmin=0,vmax=1))
imshow(x)

# %%
#plot again 

fig,axes = plt.subplots(figsize=(8,8), dpi=100, nrows=1, ncols=3)
axes[0].imshow(Inital)
axes[1].imshow(Hitmap)
axes[2].imshow(Noisemap)

plt.tight_layout()

#cbar_ax = fig.add_axes([0.98, 0.18, 0.05, 0.7])
fig.colorbar(im,fraction=0.1)

plt.show()

# %%
#mean, dev=0.0, 1.0
#inital map mean of 0 var of 1
#noise=np.random

#second task- linear scaling of noise 


#task 3- fourier space <n(p1),n(pn)>=pk 

#where there are more hits, there are less noise

# %%
#Linear Scaling of A_noise

# %%
n=10e9 #change as fits 
Scale=A_noise*n
print(Scale)
